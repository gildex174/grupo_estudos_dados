# %%
lista_frutas = ["maca.png", "banana.png", "abacaxi.jpeg"]

# %%
for img_fruta in lista_frutas:
    if "png" in img_fruta:
        print(img_fruta)
# Out:
# maca.png
# banana.png

# %%
nome = "Gildo"

# %%
nome[0]
# Out:
# 'G'

# %%
lista_frutas[1]
# Out:
# 'banana.png'

# %%
lista_frutas[0:2]
# Out:
# ['maca.png', 'banana.png']

# %%
nome[0] == "h"
# Out:
# False

# %%
nome[0:5] == "hello"
# Out:
# False

# %%
nome[:5]
# Out:
# 'Gildo'

# %%
nome[2:5]
# Out:
# 'ldo'

# %%
for i in range(0,4,2):
    print(nome[i+1])
# Out:
# i
# d

# %%
nome[len(nome) - 1]
# Out:
# 'o'

# %%
nome[-3]
# Out:
# 'l'

# %%
nome[:]
# Out:
# 'Gildo'

# %%
nome[-3:]
# Out:
# 'ldo'

# %%
def funcao_print():
    print("olá, mundo!!")

# %%
nome = funcao_print()
# Out:
# olá, mundo!!

# %%
nome

# %%
import pandas as pd

# %%
alunos = [
    {"nome": "Brastemp", "curso": "biomol", "origem": "sao carlos"},
    {"nome": "Fapesp", "curso": "biomol", "origem": "passos"},
    {"nome": "Gildo", "curso": "fiscomp", "origem": "fortaleza"},
    {"nome": "Sofia", "curso": "fisica", "origem": "resende"},
]

# %%
alunos_df = pd.DataFrame(alunos)

# %%
alunos_df
# Out:
#        nome    curso      origem
# 0  Brastemp   biomol  sao carlos
# 1    Fapesp   biomol      passos
# 2     Gildo  fiscomp   fortaleza
# 3     Sofia   fisica     resende

# %%
alunos_df[alunos_df["curso"]=="biomol"]
# Out:
#        nome   curso      origem
# 0  Brastemp  biomol  sao carlos
# 1    Fapesp  biomol      passos
